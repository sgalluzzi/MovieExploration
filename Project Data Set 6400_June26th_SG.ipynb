# %%
from sklearn import preprocessing
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import os
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import pymc3 as pm
import statsmodels.api as sm
from statsmodels.tools import add_constant
from itertools import combinations
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/Users/sethgalluzzi/Downloads/movies.csv')

# %%
df.head(1).T
# Out:
#                                                              0
# Unnamed: 0                                                   1
# title                                              Filly Brown
# title_type                                        Feature Film
# genre                                                    Drama
# runtime                                                   80.0
# mpaa_rating                                                  R
# studio                                     Indomina Media Inc.
# thtr_rel_year                                             2013
# thtr_rel_month                                               4
# thtr_rel_day                                                19
# dvd_rel_year                                            2013.0
# dvd_rel_month                                              7.0
# dvd_rel_day                                               30.0
# imdb_rating                                                5.5
# imdb_num_votes                                             899
# critics_rating                                          Rotten
# critics_score                                               45
# audience_rating                                        Upright
# audience_score                                              73
# best_pic_nom                                                no
# best_pic_win                                                no
# best_actor_win                                              no
# best_actress_win                                            no
# best_dir_win                                                no
# top200_box                                                  no
# director                                      Michael D. Olmos
# actor1                                          Gina Rodriguez
# actor2                                            Jenni Rivera
# actor3                                    Lou Diamond Phillips
# actor4                                           Emilio Rivera
# actor5                                     Joseph Julian Soria
# imdb_url                  http://www.imdb.com/title/tt1869425/
# rt_url            //www.rottentomatoes.com/m/filly_brown_2012/

# %%
df.head(5)
# Out:
#    Unnamed: 0                 title    title_type   genre  runtime  \
# 0           1           Filly Brown  Feature Film   Drama     80.0
# 1           2              The Dish  Feature Film   Drama    101.0
# 2           3   Waiting for Guffman  Feature Film  Comedy     84.0
# 3           4  The Age of Innocence  Feature Film   Drama    139.0
# 4           5           Malevolence  Feature Film  Horror     90.0
#
#   mpaa_rating                    studio  thtr_rel_year  thtr_rel_month  \
# 0           R       Indomina Media Inc.           2013               4
# 1       PG-13     Warner Bros. Pictures           2001               3
# 2           R    Sony Pictures Classics           1996               8
# 3          PG         Columbia Pictures           1993              10
# 4           R  Anchor Bay Entertainment           2004               9
#
#    thtr_rel_day  ...  best_dir_win  top200_box           director  \
# 0            19  ...            no          no   Michael D. Olmos
# 1            14  ...            no          no          Rob Sitch
# 2            21  ...            no          no  Christopher Guest
# 3             1  ...           yes          no    Martin Scorsese
# 4            10  ...            no          no        Stevan Mena
#
#               actor1              actor2                actor3  \
# 0     Gina Rodriguez        Jenni Rivera  Lou Diamond Phillips
# 1          Sam Neill    Kevin Harrington     Patrick Warburton
# 2  Christopher Guest    Catherine O'Hara          Parker Posey
# 3   Daniel Day-Lewis   Michelle Pfeiffer          Winona Ryder
# 4      Samantha Dark  R. Brandon Johnson       Brandon Johnson
#
#              actor4               actor5  \
# 0     Emilio Rivera  Joseph Julian Soria
# 1          Tom Long       Genevieve Mooy
# 2       Eugene Levy          Bob Balaban
# 3  Richard E. Grant         Alec McCowen
# 4     Heather Magee       Richard Glover
#
#                                imdb_url  \
# 0  http://www.imdb.com/title/tt1869425/
# 1  http://www.imdb.com/title/tt0205873/
# 2  http://www.imdb.com/title/tt0118111/
# 3  http://www.imdb.com/title/tt0106226/
# 4  http://www.imdb.com/title/tt0388230/
#
#                                              rt_url
# 0      //www.rottentomatoes.com/m/filly_brown_2012/
# 1                  //www.rottentomatoes.com/m/dish/
# 2   //www.rottentomatoes.com/m/waiting_for_guffman/
# 3      //www.rottentomatoes.com/m/age_of_innocence/
# 4  //www.rottentomatoes.com/m/10004684-malevolence/
#
# [5 rows x 33 columns]

# %%
df
# Out:
#      Unnamed: 0                        title    title_type  \
# 0             1                  Filly Brown  Feature Film
# 1             2                     The Dish  Feature Film
# 2             3          Waiting for Guffman  Feature Film
# 3             4         The Age of Innocence  Feature Film
# 4             5                  Malevolence  Feature Film
# ..          ...                          ...           ...
# 646         647           Death Defying Acts  Feature Film
# 647         648                   Half Baked  Feature Film
# 648         649            Dance of the Dead  Feature Film
# 649         650  Around the World in 80 Days  Feature Film
# 650         651                          LOL  Feature Film
#
#                   genre  runtime mpaa_rating                    studio  \
# 0                 Drama     80.0           R       Indomina Media Inc.
# 1                 Drama    101.0       PG-13     Warner Bros. Pictures
# 2                Comedy     84.0           R    Sony Pictures Classics
# 3                 Drama    139.0          PG         Columbia Pictures
# 4                Horror     90.0           R  Anchor Bay Entertainment
# ..                  ...      ...         ...                       ...
# 646               Drama     97.0          PG        Genius Productions
# 647              Comedy     82.0           R        Universal Pictures
# 648  Action & Adventure     87.0           R  Grindhouse Entertainment
# 649  Action & Adventure    120.0          PG      Buena Vista Pictures
# 650              Comedy     97.0       PG-13           Lionsgate Films
#
#      thtr_rel_year  thtr_rel_month  thtr_rel_day  ...  best_dir_win  \
# 0             2013               4            19  ...            no
# 1             2001               3            14  ...            no
# 2             1996               8            21  ...            no
# 3             1993              10             1  ...           yes
# 4             2004               9            10  ...            no
# ..             ...             ...           ...  ...           ...
# 646           2008               7            11  ...            no
# 647           1998               1            16  ...            no
# 648           2008               3             9  ...            no
# 649           2004               6            16  ...            no
# 650           2012               5             4  ...            no
#
#      top200_box           director             actor1                actor2  \
# 0            no   Michael D. Olmos     Gina Rodriguez          Jenni Rivera
# 1            no          Rob Sitch          Sam Neill      Kevin Harrington
# 2            no  Christopher Guest  Christopher Guest      Catherine O'Hara
# 3            no    Martin Scorsese   Daniel Day-Lewis     Michelle Pfeiffer
# 4            no        Stevan Mena      Samantha Dark    R. Brandon Johnson
# ..          ...                ...                ...                   ...
# 646          no  Gillian Armstrong         Guy Pearce  Catherine Zeta-Jones
# 647          no        Tamra Davis     Dave Chappelle        Guillermo Diaz
# 648          no       Gregg Bishop      Jared Kusnitz      Greyson Chadwick
# 649         yes       Frank Coraci        Jackie Chan          Steve Coogan
# 650          no       Liza Azuelos        Miley Cyrus            Demi Moore
#
#                    actor3              actor4               actor5  \
# 0    Lou Diamond Phillips       Emilio Rivera  Joseph Julian Soria
# 1       Patrick Warburton            Tom Long       Genevieve Mooy
# 2            Parker Posey         Eugene Levy          Bob Balaban
# 3            Winona Ryder    Richard E. Grant         Alec McCowen
# 4         Brandon Johnson       Heather Magee       Richard Glover
# ..                    ...                 ...                  ...
# 646         Timothy Spall       Saoirse Ronan          Jack Bailey
# 647            Jim Breuer    Harland Williams          Rachel True
# 648        Chandler Darby  Carissa Capobianco       Randy McDowell
# 649          Ewen Bremner         Robert Fyfe          Ian McNeice
# 650         Ashley Greene       Douglas Booth       Adam G. Sevani
#
#                                  imdb_url  \
# 0    http://www.imdb.com/title/tt1869425/
# 1    http://www.imdb.com/title/tt0205873/
# 2    http://www.imdb.com/title/tt0118111/
# 3    http://www.imdb.com/title/tt0106226/
# 4    http://www.imdb.com/title/tt0388230/
# ..                                    ...
# 646  http://www.imdb.com/title/tt0472071/
# 647  http://www.imdb.com/title/tt0120693/
# 648  http://www.imdb.com/title/tt0926063/
# 649  http://www.imdb.com/title/tt0327437/
# 650  http://www.imdb.com/title/tt1592873/
#
#                                                 rt_url
# 0         //www.rottentomatoes.com/m/filly_brown_2012/
# 1                     //www.rottentomatoes.com/m/dish/
# 2      //www.rottentomatoes.com/m/waiting_for_guffman/
# 3         //www.rottentomatoes.com/m/age_of_innocence/
# 4     //www.rottentomatoes.com/m/10004684-malevolence/
# ..                                                 ...
# 646     //www.rottentomatoes.com/m/death_defying_acts/
# 647             //www.rottentomatoes.com/m/half_baked/
# 648  //www.rottentomatoes.com/m/1203339-dance_of_th...
# 649  //www.rottentomatoes.com/m/around_the_world_in...
# 650               //www.rottentomatoes.com/m/lol_2011/
#
# [651 rows x 33 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0     runtime  thtr_rel_year  thtr_rel_month  thtr_rel_day  \
# count  651.000000  650.000000     651.000000      651.000000    651.000000
# mean   326.000000  105.821538    1997.941628        6.740399     14.416283
# std    188.071795   19.445047      10.974501        3.554223      8.861167
# min      1.000000   39.000000    1970.000000        1.000000      1.000000
# 25%    163.500000   92.000000    1990.000000        4.000000      7.000000
# 50%    326.000000  103.000000    2000.000000        7.000000     15.000000
# 75%    488.500000  115.750000    2007.000000       10.000000     21.000000
# max    651.000000  267.000000    2014.000000       12.000000     31.000000
#
#        dvd_rel_year  dvd_rel_month  dvd_rel_day  imdb_rating  imdb_num_votes  \
# count    643.000000     643.000000   643.000000   651.000000      651.000000
# mean    2004.427683       6.332815    15.007776     6.493088    57532.983103
# std        4.643588       3.378228     8.867400     1.084747   112124.386910
# min     1991.000000       1.000000     1.000000     1.900000      180.000000
# 25%     2001.000000       3.000000     7.000000     5.900000     4545.500000
# 50%     2004.000000       6.000000    15.000000     6.600000    15116.000000
# 75%     2008.000000       9.000000    23.000000     7.300000    58300.500000
# max     2015.000000      12.000000    31.000000     9.000000   893008.000000
#
#        critics_score  audience_score
# count     651.000000      651.000000
# mean       57.688172       62.362519
# std        28.402971       20.222624
# min         1.000000       11.000000
# 25%        33.000000       46.000000
# 50%        61.000000       65.000000
# 75%        83.000000       80.000000
# max       100.000000       97.000000

# %%
features = df.loc[df['title_type'] == 'Feature Film']

# %%
features['audience_score'] > 90
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 646    False
# 647    False
# 648    False
# 649    False
# 650    False
# Name: audience_score, Length: 591, dtype: bool

# %%
features['genre'].value_counts()
# Out:
# Drama                        301
# Comedy                        85
# Action & Adventure            65
# Mystery & Suspense            59
# Horror                        23
# Other                         15
# Art House & International     14
# Animation                      9
# Science Fiction & Fantasy      9
# Musical & Performing Arts      8
# Documentary                    3
# Name: genre, dtype: int64

# %%
/,
